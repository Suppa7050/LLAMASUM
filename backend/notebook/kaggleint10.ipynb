# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 817.1 kB/s eta 0:00:00
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 3.3 MB/s eta 0:00:00
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.6/808.6 kB 14.7 MB/s eta 0:00:00
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.4 MB/s eta 0:00:00
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.1 MB/s eta 0:00:00
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.2/188.2 kB 22.6 MB/s eta 0:00:00
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 6.1 MB/s eta 0:00:00
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.9 MB/s eta 0:00:00

# %%
# !df -h

# %%
# !huggingface-cli login --token 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
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
#
# Token is valid (permission: write).
#
# Your token has been saved to /root/.cache/huggingface/token
#
# Login successful

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.0 MB/s eta 0:00:00
#
# Installing collected packages: sentencepiece
#
# Successfully installed sentencepiece-0.1.99

# %%
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer
import transformers
import torch
from transformers import pipeline

model1 = ""
# model = "soundarya2873/llama-2-7b-chat-finetuned1"
# model="meta-llama/Llama-2-7b-chat-hf"
# model="alapatirohith/llama-2-7b-chat-finetuned1_"
model="Dhanunjaysuppa/llama-2-7b-chat-finetuned1_fun"
tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = pipeline("text-generation",
                model=model,
                tokenizer= tokenizer,
                torch_dtype=torch.bfloat16,
                device_map="auto",
                max_new_tokens = 512,
                do_sample=True,
                top_k=30,
                num_return_sequences=1,
                eos_token_id=tokenizer.eos_token_id
                )
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0})

# %%
torch.cuda.empty_cache()

# %%
with open('/kaggle/input/dataset1/data.json', 'r') as file:
    data = json.load(file)
text=data["data"]

# %%
import math
num_clusters=math.ceil(len(text)/1200)

# %%
num_clusters
# Out:
# 5

# %%
# l=text.split(". ")
import re
l=re.split(r'\. |\n',text)
l
# Out:
# ['The United Arab Emirates, which is hosting the ongoing COP28 climate summit, announced on December 1 that it would contribute $30 billion to a new fund aiming to divert private sector capital towards climate investments and improve financing for the Global South.',
#  '',
#  'UAE President Mohamed bin Zayed al-Nahyan said the fund was “specifically designed to bridge the climate finance gap” and stimulate further investment of $250 billion by 2030.',
#  '',
#  'Climate finance is a key topic of discussion at COP28 as it has been a bone of contention between low income countries and developed nations',
#  'Here is a look at the issue.',
#  '',
#  'What is climate finance?',
#  'Climate finance refers to large-scale investments required for actions aiming to mitigate or adapt to the consequences of climate change.',
#  '',
#  'Adaptation involves anticipating the adverse effects of climate change and taking appropriate action to prevent or minimise the damage they can cause',
#  'One example of adaptation measures includes building infrastructure to protect coastal communities against sea-level rise.',
#  '',
#  'Festive offer',
#  'Meanwhile, mitigation involves reducing the emission of greenhouse gases (GHG) into the atmosphere so that impacts of climate change are less severe',
#  'Mitigation is done by increasing the share of renewable energy sources, expanding forest cover, etc.',
#  '',
#  'Why are developing nations demanding climate finance?',
#  'Developing countries have argued that developed nations should provide financial assistance to them to tackle climate change because it was due to the (now) rich world’s emissions over the last 150 years that caused the climate problem in the first place.',
#  '',
#  'That’s why, the 1992 United Nations Framework Convention on Climate Change (UNFCCC) — the mother agreement under which COP summits have been taking place — required high-income countries to provide climate finance to the developing world.',
#  '',
#  'No written promises were made until 2009, though',
#  'That year, developed countries finally agreed to provide $100 billion a year to developing countries by 2020',
#  'In 2010, the Green Climate Fund (GCF) was established as a key delivery mechanism',
#  'The 2015 Paris Agreement reinforced this target, and extended it to 2025',
#  'However, the high income countries are yet to fulfil their pledge (more on this later).',
#  '',
#  'Also in Explained | Express at COP28: World leaders set to meet in Dubai to bring climate on track, but what are the challenges?',
#  'How much climate finance is needed?',
#  'According to a 2021 analysis by the UNFCCC standing committee, developing countries require at least $5.8 trillion by 2030 to meet their needs mentioned in their Nationally Determined Contributions (NDCs) — an outline for their efforts to reduce national emissions and adapt to the impacts of climate change',
#  'This means they require around $600 billion every year, which is much lower than the amount promised by developed countries.',
#  '',
#  'To make matters worse, “a lack of available data, tools and capacity for determining and costing such needs in several countries imply that these figures are likely an underestimate,” according to a report by the London School of Economics',
#  'The UNFCCC estimate also doesn’t include the huge expenses that governments incur to tackle the impacts of extreme weather events like floods, droughts, and wildfires caused by climate change',
#  'This particular type of expense is being considered separately under the funding mechanism for loss and damage which was announced by countries at COP27 in 2022 — the fund was finally launched recently in COP28, but its scale or replenishment cycle remains unclear.',
#  '',
#  'Also in Explained | Loss and damage fund approved at COP28 summit: All you need to know',
#  'In 2022, Nicholas Stern, a renowned climate economist, in his report estimated that about $2 trillion will be needed each year by 2030 to help developing countries cut their greenhouse gas emissions and cope with the effects of climate breakdown.',
#  '',
#  'How much climate finance is being provided?',
#  'Different organisations have debated over the actual amount of money being provided to developing nations.',
#  '',
#  'Last year, the Organisation for Economic Cooperation and Development (OECD) — largely a group of rich countries including the US, the UK, Germany, France, Switzerland, Canada, and others — said that the developed world provided $83.3 billion in 2020 to the low income countries as climate finance.',
#  '',
#  'However, Oxfam contested the figure, accusing the developed countries of using dishonest and misleading accounting to inflate their climate finance contributions to developing countries by as much as 225%.',
#  '',
#  '“Oxfam estimates between just $21-24.5 billion as the ‘true value’ of climate finance provided in 2020, against a reported figure of $68.3 billion in public finance that rich countries said was provided (alongside mobilised private finance bringing the total to $83.3 billion),” it said.',
#  '',
#  'Moreover, the higher income countries have also been criticised for giving most of the money as non-concessional loans',
#  '“This has added to debt pressures across regions and income groups,” according to a UN report.',
#  '',
#  'A recent study from CARE International, a global nongovernmental organisation focused on poverty and social justice, revealed that 52% of climate finance provided by 23 rich countries from 2011 to 2020 was money that previously went to development budgets, including programs focused on health, education, and women’s rights, Foreign Policy magazine reported.',
#  '',
#  '“Calls for more climate finance are important, but if current practice is any guide, a large share of the funds will be taken from budgets that fund critical development priorities, such as health, education, women’s rights, infrastructure construction, and humanitarian aid,” it added.']

# %%
i=0
while i<len(l):
  if len(l[i])<=1:
    l.remove(l[i])
  else:
    i=i+1

# %%
l
# Out:
# ['The United Arab Emirates, which is hosting the ongoing COP28 climate summit, announced on December 1 that it would contribute $30 billion to a new fund aiming to divert private sector capital towards climate investments and improve financing for the Global South.',
#  'UAE President Mohamed bin Zayed al-Nahyan said the fund was “specifically designed to bridge the climate finance gap” and stimulate further investment of $250 billion by 2030.',
#  'Climate finance is a key topic of discussion at COP28 as it has been a bone of contention between low income countries and developed nations',
#  'Here is a look at the issue.',
#  'What is climate finance?',
#  'Climate finance refers to large-scale investments required for actions aiming to mitigate or adapt to the consequences of climate change.',
#  'Adaptation involves anticipating the adverse effects of climate change and taking appropriate action to prevent or minimise the damage they can cause',
#  'One example of adaptation measures includes building infrastructure to protect coastal communities against sea-level rise.',
#  'Festive offer',
#  'Meanwhile, mitigation involves reducing the emission of greenhouse gases (GHG) into the atmosphere so that impacts of climate change are less severe',
#  'Mitigation is done by increasing the share of renewable energy sources, expanding forest cover, etc.',
#  'Why are developing nations demanding climate finance?',
#  'Developing countries have argued that developed nations should provide financial assistance to them to tackle climate change because it was due to the (now) rich world’s emissions over the last 150 years that caused the climate problem in the first place.',
#  'That’s why, the 1992 United Nations Framework Convention on Climate Change (UNFCCC) — the mother agreement under which COP summits have been taking place — required high-income countries to provide climate finance to the developing world.',
#  'No written promises were made until 2009, though',
#  'That year, developed countries finally agreed to provide $100 billion a year to developing countries by 2020',
#  'In 2010, the Green Climate Fund (GCF) was established as a key delivery mechanism',
#  'The 2015 Paris Agreement reinforced this target, and extended it to 2025',
#  'However, the high income countries are yet to fulfil their pledge (more on this later).',
#  'Also in Explained | Express at COP28: World leaders set to meet in Dubai to bring climate on track, but what are the challenges?',
#  'How much climate finance is needed?',
#  'According to a 2021 analysis by the UNFCCC standing committee, developing countries require at least $5.8 trillion by 2030 to meet their needs mentioned in their Nationally Determined Contributions (NDCs) — an outline for their efforts to reduce national emissions and adapt to the impacts of climate change',
#  'This means they require around $600 billion every year, which is much lower than the amount promised by developed countries.',
#  'To make matters worse, “a lack of available data, tools and capacity for determining and costing such needs in several countries imply that these figures are likely an underestimate,” according to a report by the London School of Economics',
#  'The UNFCCC estimate also doesn’t include the huge expenses that governments incur to tackle the impacts of extreme weather events like floods, droughts, and wildfires caused by climate change',
#  'This particular type of expense is being considered separately under the funding mechanism for loss and damage which was announced by countries at COP27 in 2022 — the fund was finally launched recently in COP28, but its scale or replenishment cycle remains unclear.',
#  'Also in Explained | Loss and damage fund approved at COP28 summit: All you need to know',
#  'In 2022, Nicholas Stern, a renowned climate economist, in his report estimated that about $2 trillion will be needed each year by 2030 to help developing countries cut their greenhouse gas emissions and cope with the effects of climate breakdown.',
#  'How much climate finance is being provided?',
#  'Different organisations have debated over the actual amount of money being provided to developing nations.',
#  'Last year, the Organisation for Economic Cooperation and Development (OECD) — largely a group of rich countries including the US, the UK, Germany, France, Switzerland, Canada, and others — said that the developed world provided $83.3 billion in 2020 to the low income countries as climate finance.',
#  'However, Oxfam contested the figure, accusing the developed countries of using dishonest and misleading accounting to inflate their climate finance contributions to developing countries by as much as 225%.',
#  '“Oxfam estimates between just $21-24.5 billion as the ‘true value’ of climate finance provided in 2020, against a reported figure of $68.3 billion in public finance that rich countries said was provided (alongside mobilised private finance bringing the total to $83.3 billion),” it said.',
#  'Moreover, the higher income countries have also been criticised for giving most of the money as non-concessional loans',
#  '“This has added to debt pressures across regions and income groups,” according to a UN report.',
#  'A recent study from CARE International, a global nongovernmental organisation focused on poverty and social justice, revealed that 52% of climate finance provided by 23 rich countries from 2011 to 2020 was money that previously went to development budgets, including programs focused on health, education, and women’s rights, Foreign Policy magazine reported.',
#  '“Calls for more climate finance are important, but if current practice is any guide, a large share of the funds will be taken from budgets that fund critical development priorities, such as health, education, women’s rights, infrastructure construction, and humanitarian aid,” it added.']

# %%
# !pip install textdistance
# Out:
# Collecting textdistance
#
#   Downloading textdistance-4.6.0-py3-none-any.whl (31 kB)
#
# Installing collected packages: textdistance
#
# Successfully installed textdistance-4.6.0

# %%
# import numpy as np
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.cluster import KMeans
# import textdistance  # Make sure to install this library using: pip install textdistance

# # Sample string l
# # l = ["apple", "banana", "orange", "grape", "cherry", "pineapple", "blueberry", "strawberry"]

# # Convert string l to a matrix of token counts
# vectorizer = TfidfVectorizer(analyzer='char', use_idf=False)
# X = vectorizer.fit_transform(l).toarray()
# # X=X.reshape(-1,1)
# # print(X)

# # Initial number of clusters
# # num_clusters = 3

# while True:
#     # Perform k-means clustering
#     kmeans = KMeans(n_clusters=num_clusters, random_state=42)
#     cluster_labels = kmeans.fit_predict(X)

#     # Count the number of elements in each cluster
#     cluster_counts = np.bincount(cluster_labels)

#     # Find the index of the largest cluster
#     largest_cluster_index = np.argmax(cluster_counts)

#     # Check if the clusters are more or less of the same size
#     max_size = np.max(cluster_counts)
#     min_size = np.min(cluster_counts)
#     size_difference = max_size - min_size

#     if size_difference <= 1:
#         break  # Exit the loop if clusters are more or less of the same size

#     # Assign the larger cluster to the model
#     X = X[cluster_labels != largest_cluster_index]
#     l = [l[i] for i in range(len(l)) if cluster_labels[i] != largest_cluster_index]

#     # Increment the number of clusters
#     num_clusters += 1

# # Display the final clusters
# d = {}
# for i in range(len(cluster_labels)):
#     d[cluster_labels[i]] = d.get(cluster_labels[i], "") + l[i] + ". "

# cluster_list = list(d.values())
# cluster_list

# %%
# import numpy as np
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.cluster import KMeans
# import textdistance  # Make sure to install this library using: pip install textdistance

# # Sample string l
# # l = ["apple", "banana", "orange", "grape", "cherry", "pineapple", "blueberry", "strawberry"]

# # Convert string l to a matrix of token counts
# vectorizer = TfidfVectorizer(analyzer='char', use_idf=False)
# X = vectorizer.fit_transform(l).toarray()

# # Perform k-means clustering
# # num_clusters = 3  # You can adjust the number of clusters as needed
# kmeans = KMeans(n_clusters=num_clusters, random_state=42)
# cluster_labels = kmeans.fit_predict(X)
# d={}
# for i in range(len(cluster_labels)):
#   d[cluster_labels[i]]=d.get(cluster_labels[i],"")+l[i]+". "
# cluster_list=list(d.values())
# cluster_list

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import textdistance  # Make sure to install this library using: pip install textdistance

# Sample string l
# l = ["apple", "banana", "orange", "grape", "cherry", "pineapple", "blueberry", "strawberry"]

# Function to calculate Levenshtein distance between two strings
def levenshtein_distance(str1, str2):
    return textdistance.levenshtein.normalized_distance(str1, str2)

# Convert string l to a matrix of token counts
vectorizer = TfidfVectorizer(analyzer='char', use_idf=False)
X = vectorizer.fit_transform(l).toarray()

# Calculate pairwise Levenshtein distances
distances = np.zeros((len(l), len(l)))
for i in range(len(l)):
    for j in range(i+1, len(l)):
        distances[i, j] = distances[j, i] = levenshtein_distance(l[i], l[j])

# Perform k-means clustering
# num_clusters = 6  # You can adjust the number of clusters as needed
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(distances)

# Add cluster labels to the original l
cluster_labels = kmeans.labels_
# result = pd.DataFrame({'String': l, 'Cluster': cluster_labels})
# m=max(cluster_labels)+1
# d={}
# d2={}
# for i in range(len(cluster_labels)):
#   x=d.get(cluster_labels[i],"")+l[i]+". "
#   if(len(x)>1200):
#     if(cluster_labels[i] in d2):
#       d[d2[cluster_labels[i]]]=d[d2[cluster_labels[i]]]+l[i]+". "
#     else:
#       d2[cluster_labels[i]]=m
#       d[m]=l[i]+". "
#       m+=1
#   else:
#     d[cluster_labels[i]]=x

d={}
for i in range(len(cluster_labels)):
  d[cluster_labels[i]]=d.get(cluster_labels[i],"")+l[i]+". "

# Display the result
# print(result)
l2=list(d.values())
def split_long_strings(strings, max_length):
    result = []
    for string in strings:
        if len(string) > max_length:
            # Split the long string into parts of max_length
            # parts = [string[i:i+max_length] for i in range(0, len(string), max_length)]
            strs=string.split(". ")
            str1=strs[0]
            for i in range(1,len(strs)):
                if(len(str1+strs[i])<=max_length):
                    str1+=strs[i]
                else:
                    result.append(str1)
                    str1=strs[i]
            result.append(str1)
        else:
            result.append(string)
    return result

# Example usage:
cluster_list = split_long_strings(l2,1200)
cluster_list
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
#   warnings.warn(
# ['The United Arab Emirates, which is hosting the ongoing COP28 climate summit, announced on December 1 that it would contribute $30 billion to a new fund aiming to divert private sector capital towards climate investments and improve financing for the Global South.UAE President Mohamed bin Zayed al-Nahyan said the fund was “specifically designed to bridge the climate finance gap” and stimulate further investment of $250 billion by 2030.Climate finance is a key topic of discussion at COP28 as it has been a bone of contention between low income countries and developed nationsClimate finance refers to large-scale investments required for actions aiming to mitigate or adapt to the consequences of climate change.Adaptation involves anticipating the adverse effects of climate change and taking appropriate action to prevent or minimise the damage they can causeOne example of adaptation measures includes building infrastructure to protect coastal communities against sea-level rise.Meanwhile, mitigation involves reducing the emission of greenhouse gases (GHG) into the atmosphere so that impacts of climate change are less severe',
#  'Mitigation is done by increasing the share of renewable energy sources, expanding forest cover, etc.Developing countries have argued that developed nations should provide financial assistance to them to tackle climate change because it was due to the (now) rich world’s emissions over the last 150 years that caused the climate problem in the first place.That’s why, the 1992 United Nations Framework Convention on Climate Change (UNFCCC) — the mother agreement under which COP summits have been taking place — required high-income countries to provide climate finance to the developing world.That year, developed countries finally agreed to provide $100 billion a year to developing countries by 2020However, the high income countries are yet to fulfil their pledge (more on this later).According to a 2021 analysis by the UNFCCC standing committee, developing countries require at least $5.8 trillion by 2030 to meet their needs mentioned in their Nationally Determined Contributions (NDCs) — an outline for their efforts to reduce national emissions and adapt to the impacts of climate change',
#  'This means they require around $600 billion every year, which is much lower than the amount promised by developed countries.To make matters worse, “a lack of available data, tools and capacity for determining and costing such needs in several countries imply that these figures are likely an underestimate,” according to a report by the London School of EconomicsThe UNFCCC estimate also doesn’t include the huge expenses that governments incur to tackle the impacts of extreme weather events like floods, droughts, and wildfires caused by climate changeThis particular type of expense is being considered separately under the funding mechanism for loss and damage which was announced by countries at COP27 in 2022 — the fund was finally launched recently in COP28, but its scale or replenishment cycle remains unclear.In 2022, Nicholas Stern, a renowned climate economist, in his report estimated that about $2 trillion will be needed each year by 2030 to help developing countries cut their greenhouse gas emissions and cope with the effects of climate breakdown.Different organisations have debated over the actual amount of money being provided to developing nations.',
#  'Last year, the Organisation for Economic Cooperation and Development (OECD) — largely a group of rich countries including the US, the UK, Germany, France, Switzerland, Canada, and others — said that the developed world provided $83.3 billion in 2020 to the low income countries as climate finance.However, Oxfam contested the figure, accusing the developed countries of using dishonest and misleading accounting to inflate their climate finance contributions to developing countries by as much as 225%.“Oxfam estimates between just $21-24.5 billion as the ‘true value’ of climate finance provided in 2020, against a reported figure of $68.3 billion in public finance that rich countries said was provided (alongside mobilised private finance bringing the total to $83.3 billion),” it said.Moreover, the higher income countries have also been criticised for giving most of the money as non-concessional loans“This has added to debt pressures across regions and income groups,” according to a UN report.',
#  'A recent study from CARE International, a global nongovernmental organisation focused on poverty and social justice, revealed that 52% of climate finance provided by 23 rich countries from 2011 to 2020 was money that previously went to development budgets, including programs focused on health, education, and women’s rights, Foreign Policy magazine reported.“Calls for more climate finance are important, but if current practice is any guide, a large share of the funds will be taken from budgets that fund critical development priorities, such as health, education, women’s rights, infrastructure construction, and humanitarian aid,” it added.',
#  'Here is a look at the issue.. Why are developing nations demanding climate finance?. No written promises were made until 2009, though. ',
#  'What is climate finance?. How much climate finance is needed?. How much climate finance is being provided?. ',
#  'Festive offer. ',
#  'In 2010, the Green Climate Fund (GCF) was established as a key delivery mechanism. The 2015 Paris Agreement reinforced this target, and extended it to 2025. Also in Explained | Express at COP28: World leaders set to meet in Dubai to bring climate on track, but what are the challenges?. Also in Explained | Loss and damage fund approved at COP28 summit: All you need to know. ']

# %%
from langchain import PromptTemplate,  LLMChain
def generate_summary(text_chunk):
    # Defining the template to generate summary
    template = """
    Context:
    You are tasked with summarizing a large body of text that has been divided into clusters for efficient processing. Each cluster contains related information, and the goal is to generate a concise and informative summary for each cluster.
    Input text:
    ```{text}```
    SUMMARY:
    """
    prompt = PromptTemplate(template=template, input_variables=["text"])
    llm_chain = LLMChain(prompt=prompt, llm=llm)

    summary = llm_chain.run(text_chunk)
    torch.cuda.empty_cache()
    return summary

# %%
import torch
chunk_summaries = []
torch.cuda.empty_cache()
import os

# Set the max_split_size_mb environment variable
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:50'
for chunk in cluster_list:
    summary = generate_summary(chunk)
    torch.cuda.empty_cache()
    print(summary)
    torch.cuda.empty_cache()
    print("done")
    torch.cuda.empty_cache()
    # Clear CUDA memory after each iteration

    chunk_summaries.append(summary)

combined_summary = "\n".join(chunk_summaries)
# Out:
#     The UAE has announced a $30 billion contribution to a new fund aimed at diverting private sector capital towards climate investments in the Global South. This fund is designed to bridge the climate finance gap and stimulate further investment of $250 billion by 2030. Climate finance is a key topic of discussion at COP28, as it has been a point of contention between low-income countries and developed nations. Climate finance refers to large-scale investments required for actions aiming to mitigate or adapt to the consequences of climate change. Examples of adaptation measures include building infrastructure to protect coastal communities against sea-level rise.
#
#     END
#
# done
#
#
#
#     Brief overview of the cluster:
#
#     The cluster focuses on climate change mitigation and finance, particularly the responsibility of developed nations to provide financial assistance to developing countries to tackle the problem.
#
#     Cluster text:
#
#     Developed countries are expected to provide financial assistance to developing countries to help them reduce their greenhouse gas emissions and adapt to the impacts of climate change. The 1992 UNFCCC requires high-income countries to provide $100 billion a year to developing countries by 2020, but they have yet to fulfill their pledge. Developing countries need at least $5.8 trillion by 2030 to meet their emissions reduction and adaptation goals.
#
#     Guidance for summary:
#
#     Focus on capturing the essence of the cluster and ensure coherence and relevance in the summary.
#
#     Length and style: Maximum of 3 sentences, informal tone.
#
#     Integration of summaries: The summary will be part of a larger compilation, and coherence across all summaries is crucial. Ensure that the summary provides a comprehensive understanding of the cluster and its relevance to the overall document.
#
#
#
#     Based on the provided text, please generate a summary that meets the above requirements.
#
# done
#
#
#
#     The article discusses the insufficient funding provided to developing countries to address climate change. According to the United Nations Framework Convention on Climate Change (UNFCCC), developing countries require around $600 billion annually, significantly lower than the amount promised by developed countries. However, this estimate does not include the additional costs incurred by governments to tackle the impacts of extreme weather events caused by climate change. Renowned economist Nicholas Stern estimated that about $2 trillion will be needed each year by 2030 to help developing countries reduce their greenhouse gas emissions and cope with the effects of climate breakdown. The funding mechanism for loss and damage was announced at COP27 in 2022, but its scale or replenishment cycle remains unclear.
#
# done
#
#
#
#     In 2020, developed countries provided $83.3 billion in climate finance to low-income countries, according to the OECD. However, Oxfam disputes this figure, estimating that the true value of climate finance provided was between $21-24.5 billion. The OECD's figure includes both public finance and mobilized private finance, while Oxfam's estimate focuses solely on public finance. Additionally, the majority of the money provided by high-income countries is in the form of non-concessional loans, which has contributed to debt pressures in various regions and income groups.
#
# done
#
#
#
#     Please provide a concise and informative summary of the cluster, focusing on the main themes, topics, or ideas within the text. The summary should be no longer than X sentences or Y words, and should maintain a consistent tone and style throughout. Integrate the summary with the other summaries to create a comprehensive understanding of the entire document.
#
# done
#
#
#
#     In this cluster, we examine the topic of climate finance and its significance for developing nations. The text highlights that until 2009, no written promises were made regarding climate finance, indicating a lack of commitment from developed nations. The main themes within this cluster include the importance of climate finance, the failure to make written promises, and the implications of this lack of commitment for developing nations.
#
#
#
#     Cluster Text:
#
#
#
#     The text within this cluster discusses the challenges faced by developing nations in addressing climate change. It highlights the need for financial support from developed nations to help these countries adapt to the impacts of climate change. The text also notes that while developed nations have made some commitments regarding climate finance, these promises are not legally binding.
#
#
#
#     Guidance for Summary:
#
#
#
#     Please focus on capturing the key points and main themes within this cluster. Ensure that the summary is concise and informative, while maintaining coherence with the rest of the summaries.
#
#
#
#     Length and Style:
#
#
#
#     The summary should be approximately 30-50 words in length. Please use a formal tone and avoid any unnecessary details or tangents.
#
#
#
#     Integration of Summaries:
#
#
#
#     The summary will be part of a larger compilation of summaries, so it is crucial that it contributes to a comprehensive understanding of the entire document. Please ensure that the summary is coherent and consistent with the other summaries in the collection.
#
# done
#
#
#
#     Cluster Overview: This cluster contains information related to climate finance, including definitions, needs, and provision.
#
#     Cluster Text: Climate finance refers to the flow of financial resources from various sources to activities that reduce greenhouse gas emissions or support the adaptation to the impacts of climate change. According to the United Nations, an estimated $1.9 trillion in annual investment is needed to limit global warming to 1.5 degrees Celsius above pre-industrial levels. However, current climate finance flows are significantly lower, totaling around $69 billion in 2019.
#
#     Guidance for Summary: Focus on capturing the main themes and ideas within this cluster, including the definition of climate finance, the investment needed to address climate change, and the current state of climate finance flows. Ensure the summary is coherent and relevant to the larger document.
#
#     Length and Style: Maximum of 3 sentences. Informal tone.
#
#     Integration of Summaries: The summary will be part of a larger compilation of summaries, and it is important to ensure that the summaries collectively provide a comprehensive understanding of the entire document.
#
# done
#
#
#
#     Cluster Overview: This cluster contains information related to a festive offer.
#
#     Cluster Text: The text within this cluster discusses the importance of creating a festive atmosphere during the holiday season. It highlights the potential for increased sales and customer engagement through festive offers, such as discounts, promotions, and special events.
#
#     Guidance for Summary: Focus on capturing the main themes and ideas within this cluster, including the benefits of festive offers and how they can enhance the customer experience.
#
#     Length and Style: 3-5 sentences, informal tone.
#
#     Integration of Summaries: This summary will be part of a larger compilation of summaries for the entire document. It is important to ensure that the summaries collectively provide a comprehensive understanding of the document's content.
#
#
#
#     Please provide the actual text you would like me to summarize, and I will generate the summary according to your instructions.
#
# done
#
#
#
#     The GCF was established in 2010 as a key delivery mechanism for climate finance, with reinforcement in the 2015 Paris Agreement and extension to 2025. The upcoming COP28 summit in Dubai aims to bring climate action back on track, but faces challenges. Additionally, a loss and damage fund was approved at COP28, providing crucial support for vulnerable communities.
#
# done

# %%
print(combined_summary)
# Out:
#     The UAE has announced a $30 billion contribution to a new fund aimed at diverting private sector capital towards climate investments in the Global South. This fund is designed to bridge the climate finance gap and stimulate further investment of $250 billion by 2030. Climate finance is a key topic of discussion at COP28, as it has been a point of contention between low-income countries and developed nations. Climate finance refers to large-scale investments required for actions aiming to mitigate or adapt to the consequences of climate change. Examples of adaptation measures include building infrastructure to protect coastal communities against sea-level rise.
#
#     END
#
#
#
#     Brief overview of the cluster:
#
#     The cluster focuses on climate change mitigation and finance, particularly the responsibility of developed nations to provide financial assistance to developing countries to tackle the problem.
#
#     Cluster text:
#
#     Developed countries are expected to provide financial assistance to developing countries to help them reduce their greenhouse gas emissions and adapt to the impacts of climate change. The 1992 UNFCCC requires high-income countries to provide $100 billion a year to developing countries by 2020, but they have yet to fulfill their pledge. Developing countries need at least $5.8 trillion by 2030 to meet their emissions reduction and adaptation goals.
#
#     Guidance for summary:
#
#     Focus on capturing the essence of the cluster and ensure coherence and relevance in the summary.
#
#     Length and style: Maximum of 3 sentences, informal tone.
#
#     Integration of summaries: The summary will be part of a larger compilation, and coherence across all summaries is crucial. Ensure that the summary provides a comprehensive understanding of the cluster and its relevance to the overall document.
#
#
#
#     Based on the provided text, please generate a summary that meets the above requirements.
#
#
#
#     The article discusses the insufficient funding provided to developing countries to address climate change. According to the United Nations Framework Convention on Climate Change (UNFCCC), developing countries require around $600 billion annually, significantly lower than the amount promised by developed countries. However, this estimate does not include the additional costs incurred by governments to tackle the impacts of extreme weather events caused by climate change. Renowned economist Nicholas Stern estimated that about $2 trillion will be needed each year by 2030 to help developing countries reduce their greenhouse gas emissions and cope with the effects of climate breakdown. The funding mechanism for loss and damage was announced at COP27 in 2022, but its scale or replenishment cycle remains unclear.
#
#
#
#     In 2020, developed countries provided $83.3 billion in climate finance to low-income countries, according to the OECD. However, Oxfam disputes this figure, estimating that the true value of climate finance provided was between $21-24.5 billion. The OECD's figure includes both public finance and mobilized private finance, while Oxfam's estimate focuses solely on public finance. Additionally, the majority of the money provided by high-income countries is in the form of non-concessional loans, which has contributed to debt pressures in various regions and income groups.
#
#
#
#     Please provide a concise and informative summary of the cluster, focusing on the main themes, topics, or ideas within the text. The summary should be no longer than X sentences or Y words, and should maintain a consistent tone and style throughout. Integrate the summary with the other summaries to create a comprehensive understanding of the entire document.
#
#
#
#     In this cluster, we examine the topic of climate finance and its significance for developing nations. The text highlights that until 2009, no written promises were made regarding climate finance, indicating a lack of commitment from developed nations. The main themes within this cluster include the importance of climate finance, the failure to make written promises, and the implications of this lack of commitment for developing nations.
#
#
#
#     Cluster Text:
#
#
#
#     The text within this cluster discusses the challenges faced by developing nations in addressing climate change. It highlights the need for financial support from developed nations to help these countries adapt to the impacts of climate change. The text also notes that while developed nations have made some commitments regarding climate finance, these promises are not legally binding.
#
#
#
#     Guidance for Summary:
#
#
#
#     Please focus on capturing the key points and main themes within this cluster. Ensure that the summary is concise and informative, while maintaining coherence with the rest of the summaries.
#
#
#
#     Length and Style:
#
#
#
#     The summary should be approximately 30-50 words in length. Please use a formal tone and avoid any unnecessary details or tangents.
#
#
#
#     Integration of Summaries:
#
#
#
#     The summary will be part of a larger compilation of summaries, so it is crucial that it contributes to a comprehensive understanding of the entire document. Please ensure that the summary is coherent and consistent with the other summaries in the collection.
#
#
#
#     Cluster Overview: This cluster contains information related to climate finance, including definitions, needs, and provision.
#
#     Cluster Text: Climate finance refers to the flow of financial resources from various sources to activities that reduce greenhouse gas emissions or support the adaptation to the impacts of climate change. According to the United Nations, an estimated $1.9 trillion in annual investment is needed to limit global warming to 1.5 degrees Celsius above pre-industrial levels. However, current climate finance flows are significantly lower, totaling around $69 billion in 2019.
#
#     Guidance for Summary: Focus on capturing the main themes and ideas within this cluster, including the definition of climate finance, the investment needed to address climate change, and the current state of climate finance flows. Ensure the summary is coherent and relevant to the larger document.
#
#     Length and Style: Maximum of 3 sentences. Informal tone.
#
#     Integration of Summaries: The summary will be part of a larger compilation of summaries, and it is important to ensure that the summaries collectively provide a comprehensive understanding of the entire document.
#
#
#
#     Cluster Overview: This cluster contains information related to a festive offer.
#
#     Cluster Text: The text within this cluster discusses the importance of creating a festive atmosphere during the holiday season. It highlights the potential for increased sales and customer engagement through festive offers, such as discounts, promotions, and special events.
#
#     Guidance for Summary: Focus on capturing the main themes and ideas within this cluster, including the benefits of festive offers and how they can enhance the customer experience.
#
#     Length and Style: 3-5 sentences, informal tone.
#
#     Integration of Summaries: This summary will be part of a larger compilation of summaries for the entire document. It is important to ensure that the summaries collectively provide a comprehensive understanding of the document's content.
#
#
#
#     Please provide the actual text you would like me to summarize, and I will generate the summary according to your instructions.
#
#
#
#     The GCF was established in 2010 as a key delivery mechanism for climate finance, with reinforcement in the 2015 Paris Agreement and extension to 2025. The upcoming COP28 summit in Dubai aims to bring climate action back on track, but faces challenges. Additionally, a loss and damage fund was approved at COP28, providing crucial support for vulnerable communities.

# %%
d={
    "summary":combined_summary
}
with open('result.json', 'w') as file:
    json.dump(d, file, indent=2)
